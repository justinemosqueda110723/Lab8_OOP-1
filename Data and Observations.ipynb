# %%
class Car: 
    def __init__(self, brand, model): 
        self.brand = brand 
        self.model = model 
 
    def display_info(self): 
        return f"Car: {self.brand} {self.model}" 
 
my_car = Car("Toyota", "Corolla") 
print(my_car.display_info())
# Out:
# Car: Toyota Corolla

# %%
class Student: 
    def __init__(self, name, grade): 
        self.name = name 
        self.grade = grade 
 
    def get_info(): 
        return f"Student: {self.name}, Grade: {self.grade}"
 
student1 = Student("Allen", "A") 
print(student1.get_info())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       7         return f"Student: {self.name}, Grade: {self.grade}"
#       9 student1 = Student("Allen", "A")
# ---> 10 print(student1.get_info())
#
# TypeError: Student.get_info() takes 0 positional arguments but 1 was given

# %%
class BankAccount: 
    def __init__(self, account_holder, balance): 
        self.__balance = balance  # Private attribute 
        self.account_holder = account_holder 
 
    def deposit(self, amount): 
        self.__balance += amount 
        return f"New Balance: {self.__balance}" 
 
    def get_balance(self): 
        return f"Balance: {self.__balance}" 
 
account = BankAccount("John Doe", 1000) 
print(account.deposit(500)) 
print(account.get_balance())
# Out:
# New Balance: 1500
# Balance: 1500

# %%
class Animal: 
    def speak(self): 
        return "Some sound" 
class Dog(Animal): 
    def speak(self): 
        return "Bark!" 
dog = Dog() 
print(dog.speak())
# Out:
# Bark!

# %%
class Vehicle: 
    def move(self): 
        return "Vehicle is moving" 
class Car(Vehicle): 
    def fuel_type(self): 
        return "Uses gasoline" 
class ElectricCar(Car): 
    def fuel_type(self): 
        return "Uses electricity" 
    
tesla = ElectricCar() 
print(tesla.move()) 
print(tesla.fuel_type())
# Out:
# Vehicle is moving
# Uses electricity

# %%
class Device: 
    def power_on(self): 
        return "Device is turning on" 
class Smartphone(Device): 
    def power_on(self): 
        return "Smartphone is booting up" 
  
phone = Smartphone() 
print(phone.power_on())
# Out:
# Smartphone is booting up

# %%
class Box:
    def __init__(self, weight):
        self.weight = weight

    def __add__(self, other):
        # Create and return a NEW Box object with the combined weight
        return Box(self.weight + other.weight)

box1 = Box(5)
box2 = Box(10)
box3 = box1 + box2 # Now box3 is a Box object with weight 15

print(f"Total weight: {box3.weight} kg")
# Out:
# Total weight: 15 kg

# %%
from abc import ABC, abstractmethod 

class Appliance(ABC): 
    @abstractmethod 
    def turn_on(self): 
        pass 

class Fan(Appliance): 
    def turn_on(self): 
        return "Fan is spinning" 

fan = Fan() 
print(fan.turn_on())
# Out:
# Fan is spinning

# %%
class Engine: 
    def start(self): 
        return "Engine started" 
class Wheels: 
    def roll(self): 
        return "Wheels rolling" 
class Car(Engine, Wheels): 
    def drive(self): 
        return "Car is moving" 
    
my_car = Car() 
print(my_car.start()) 
print(my_car.roll()) 
print(my_car.drive())
# Out:
# Engine started
# Wheels rolling
# Car is moving

# %%
class MathOperations: 
    @staticmethod 
    def square(num): 
        return num * num 
 
number = int(input("Enter a number: ")) 
print("Square:", MathOperations.square(number))
# Out:
# Square: 144

# %%
class Book: 
    def __init__(self, title, author): 
        self.title = title 
        self.author = author 
    def get_info(self): 
        return f"{self.title} by {self.author}" 

book1 = Book("1984") 
print(book1.get_info())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 8
#       5     def get_info(self):
#       6         return f"{self.title} by {self.author}"
# ----> 8 book1 = Book("1984")
#       9 print(book1.get_info())
#
# TypeError: Book.__init__() missing 1 required positional argument: 'author'

# %%
class Product: 
    def __init__(self, name, price): 
        self.name = name 
        self.price = price 
    def get_details(self): 
        return f"{self.name} costs ${self.price}"
product1 = Product("Laptop", 1200) 
print(product1.get_details())
# Out:
# Laptop costs $1200

# %%
class Person: 
    def __init__(self, name): 
        self.name = name 
    def greet(): 
        return f"Hello, {self.name}"  
p = Person("Alice") 
print(p.greet())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 7
#       5         return f"Hello, {self.name}"
#       6 p = Person("Alice")
# ----> 7 print(p.greet())
#
# TypeError: Person.greet() takes 0 positional arguments but 1 was given

# %%
class ATM: 
    def __init__(self, balance): 
        self.balance = balance 
    def withdraw(self, amount): 
        if amount > self.balance: 
            return "Insufficient balance" 
        self.balance -= amount 
        return f"Withdrawn {amount}, Remaining balance: {self.balance}"

atm = ATM(1000) 
print(atm.withdraw(200))
# Out:
# Withdrawn 200, Remaining balance: 800

# %%
class Employee: 
    def __init__(self, name, salary): 
        self.name = name 
        self.salary = salary  

emp1 = Employee("Michael", 5000) 
print(emp1.display())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 7
#       4         self.salary = salary
#       6 emp1 = Employee("Michael", 5000)
# ----> 7 print(emp1.display())
#
# AttributeError: 'Employee' object has no attribute 'display'

# %%
class Patient: 
    def __init__(self, name, age, disease): 
        self.name = name 
        self.age = age 
        self.disease = disease

    def get_info(self): 
        return f"Patient: {self.name}, Age: {self.age}, Disease: {self.disease}" 
    
patient1 = Patient("John Cruz", 45, "Diabetes") 
print(patient1.get_info())
# Out:
# Patient: John Cruz, Age: 45, Disease: Diabetes

# %%
class Teacher: 
    def __init__(self, name, subject): 
        self.name = name 
        self.subject = subject 
    def teach(self): 
        return f"{self.name} is teaching {self.subject}"  

teacher1 = Teacher("Mr. Smith", "Mathematics") 
print(teacher1.teach())
# Out:
# Mr. Smith is teaching Mathematics

# %%
class Flight: 
    def __init__(self, flight_number, destination): 
        self.flight_number = flight_number 
        self.destination = destination 
    def book_ticket(self): 
        return f"Ticket booked for flight {self.flight_number} to {self.destination}" 

flight1 = Flight(101) 
print(flight1.book_ticket())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 8
#       5     def book_ticket(self):
#       6         return f"Ticket booked for flight {self.flight_number} to {self.destination}"
# ----> 8 flight1 = Flight(101)
#       9 print(flight1.book_ticket())
#
# TypeError: Flight.__init__() missing 1 required positional argument: 'destination'

# %%
class SmartDevice: 
    def __init__(self, device_name, status="Off"): 
        self.device_name = device_name 
        self.status = status 
    def turn_on(self): 
        self.status = "On" 
        return f"{self.device_name} is now {self.status}" 

light = SmartDevice("Living Room Light") 
print(light.turn_on())
# Out:
# Living Room Light is now On

# %%
class Library: 
    def __init__(self): 
        self.books = [] 
    def add_book(self, title): 
        self.books.append(title) 
        return f"Book '{title}' added to the library" 
    def show_books(self): 
        return f"Available Books: {', '.join(self.books)}" 

library = Library() 
print(library.add_book("Python Programming")) 
print(library.show_books())
# Out:
# Book 'Python Programming' added to the library
# Available Books: Python Programming

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.is_available = True

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, title, author):
        self.books.append(Book(title, author))
        print(f"Book '{title}' added successfully.")

    def borrow_book(self, title):
        for book in self.books:
            if book.title.lower() == title.lower():
                if book.is_available:
                    book.is_available = False
                    return f"You have borrowed '{book.title}'."
                return f"'{book.title}' is already borrowed."
        return "Book not found."

    def return_book(self, title):
        for book in self.books:
            if book.title.lower() == title.lower():
                book.is_available = True
                return f"'{book.title}' returned successfully."
        return "Book not found."

    def show_status(self):
        print("\n--- Library Inventory ---")
        for book in self.books:
            status = "Available" if book.is_available else "Borrowed"
            print(f"{book.title} by {book.author} - [{status}]")

# Example Usage
my_lib = Library()
my_lib.add_book("Python Basics", "A. Sweigart")
my_lib.add_book("Clean Code", "R. Martin")
print(my_lib.borrow_book("Python Basics"))
my_lib.show_status()
# Out:
# Book 'Python Basics' added successfully.
# Book 'Clean Code' added successfully.
# You have borrowed 'Python Basics'.
#
# --- Library Inventory ---
# Python Basics by A. Sweigart - [Borrowed]
# Clean Code by R. Martin - [Available]
